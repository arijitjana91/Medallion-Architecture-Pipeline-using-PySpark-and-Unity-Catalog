# %%
df = spark.read.table("medallion_arc_e2e.bronze.regions")

# %%
display(df)

# %%
df = df.drop("_rescued_data")

display(df)

# %%
df.write.format("delta").mode("overwrite")\
    .option("path","abfss://silver-e2e-eus-p01@adlsdemodatabrickseus202.dfs.core.windows.net/regions")\
    .saveAsTable("medallion_arc_e2e.silver.regions")

# %%
# Register as external table in Unity Catalog
spark.sql("""
CREATE TABLE IF NOT EXISTS medallion_arc_e2e.silver.regions
USING DELTA
LOCATION 'abfss://silver-e2e-eus-p01@adlsdemodatabrickseus202.dfs.core.windows.net/regions'
""")

# %%
df = spark.read.table("medallion_arc_e2e.silver.regions")

display(df)

# %%
spark
