# %%
df = spark.read.table("medallion_arc_e2e.bronze.regions")

# %%
display(df)

# %%
df = df.drop("_rescued_data")

display(df)

# %%
df.write.format("delta").mode("overwrite")\
    .save("abfss://silver-e2e-eus-p01@adlsdemodatabrickseus202.dfs.core.windows.net/regions")

# %%
try:    df = spark.read.format("delta").load("abfss://silver-e2e-eus-p01@adlsdemodatabrickseus202.dfs.core.windows.net/products")
except AnalysisException as e:
    print(f"Error loading data: {e}")


display(df)
