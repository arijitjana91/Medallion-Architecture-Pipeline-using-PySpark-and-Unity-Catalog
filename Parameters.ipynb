# %%
datasets = [
    {
        "file_name" : "orders"
    },
    {
        "file_name" : "products"
    },
    {
        "file_name" : "customers"
    }
]

# %%
# dbutils.jobs.taskValues.set("output_datasets", datasets, scopes = "notebook")
dbutils.jobs.taskValues.set("output_datasets", datasets)
